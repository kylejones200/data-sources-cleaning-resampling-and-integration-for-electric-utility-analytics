# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/jnesnky/ercot/combinedfile.csv")

# %%
df.head()
# Out:
#           COAST         EAST        ERCOT  FAR_WEST        FWEST  \
# 0  10377.230060  1123.140667  32922.36323       NaN  2305.249168
# 1   8651.650851   976.945021  28555.93188       NaN  2779.885423
# 2   8977.337782  1203.596917  33309.96088       NaN  3551.595592
# 3   8977.337782  1203.596917  33309.96088       NaN  3551.595592
# 4   8902.438470  1072.429936  30232.55855       NaN  3428.210015
#
#           NCENT       NORTH  NORTH_C        SCENT        SOUTH  SOUTHERN  \
# 0   9822.300670  639.723283      NaN  4927.413916  2835.730591       NaN
# 1   7958.635497  598.894799      NaN  4259.757445  2410.013254       NaN
# 2  10419.496780  718.922146      NaN  5057.106325  2282.243514       NaN
# 3  10419.496780  718.922146      NaN  5057.106325  2282.243514       NaN
# 4   8397.854969  555.724751      NaN  4710.644878  2243.966794       NaN
#
#    SOUTH_C         WEST          date      hour_end           end
# 0      NaN   891.574881  11/5/17 2:00  11/5/17 1:00  11/5/17 1:00
# 1      NaN   920.149590  11/4/18 2:00  11/4/18 1:00  11/4/18 1:00
# 2      NaN  1099.661819  11/3/19 2:00  11/3/19 1:00  11/3/19 1:00
# 3      NaN  1099.661819  11/3/19 2:00  11/3/19 1:00  11/3/19 1:00
# 4      NaN   921.288740  11/1/20 2:00  11/1/20 1:00  11/1/20 1:00

# %%
df["end"] = pd.to_datetime(df["end"])

# %%
df.set_index("end", inplace = True)

# %%
df.to_csv("/Users/jnesnky/ercot/combinedfile_datetime.csv")

# %%
df["ERCOT"].plot()

# %%
# %matplotlib inline
